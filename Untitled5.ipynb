# %% [markdown]
# ## len of integer
#
# #### n1 = 2431234  -> 7
# ####  n2 = 23423    -> 5
# ####  n3 = 1212     -> 4

# %%
n = int(input("give me number"))

print(n)

len(str(n))
# Out:
# give me number 757665
# 757665
# 6

# %%
a=5765
n = a//10
print(n)

a=576
n = a//10
print(n)

a=57
n = a//10
print(n)

a=5
n = a//10
print(n)
# Out:
# 576
# 57
# 5
# 0

# %%
n= int(input("number len"))


count = 0
while n>0:
    count+=1
    n=n//10

count
# Out:
# number len 76576
# 5

# %%
a="bobthedog"
print(a[::-1])
# Out:
# godehtbob

# %%
n=123467467
print(n)
temp=str(n)
rev=temp[::-1]

result =int(rev)
print(result)
# Out:
# 123467467
# 764764321

# %%
123423%10
# Out:
# 3

# %%
n= int(input("number len"))

rev_order=0
count = 0
while n>0:
    temp=n%10
    rev_order=(rev_order*10)+temp
    count+=1
    n=n//10

print(count)
print(rev_order)
# Out:
# number len 1234
# 4
# 24321
