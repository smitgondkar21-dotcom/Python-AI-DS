# %%
import pyfiglet

fonts = pyfiglet.FigletFont.getFonts()

for font in fonts:
    print(font)

# print(pyfiglet.figlet_format(text, font="slant"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pyfiglet
#       2
#       3 fonts = pyfiglet.FigletFont.getFonts()
#       4
#
# ModuleNotFoundError: No module named 'pyfiglet'
