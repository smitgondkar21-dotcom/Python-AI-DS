# %%
# why small values have the same address?

a=12345456346

print(id(a))

del(a)

a=12345456346

print(id(a))
# Out:
# 4433243120
# 4433243696

# %%
a=12

print(id(a))

del(a)

a=12

print(id(a))
# Out:
# 4309591160
# 4309591160

# %%
a="bob"
b="tom"
c="bob"
d=b

# %%
x=10
y=x
y=y+123

# %%
name=input("please give me the name!-->")
age=input("your age-->")
print(name)

print(type(age))
# Out:
# please give me the name!--> dfasdf
# your age--> 1
# dfasdf
# <class 'str'>

# %%
123+3
# Out:
# 126

# %%
# calc

first_val=input("first value")

second_val=input("second_val")

print(first_val+second_val)
# Out:
# first value 123
# second_val 12
# 12312

# %%
# calc

first_val=int(input("first value"))

second_val=int(input("second_val"))

print(first_val+second_val)
# Out:
# first value 123
# second_val 12
# 135

# %%
#area of triangle

a=int(input("first value"))
b=int(input("first value"))
area=1/2*(a*b)
print(area)

# %%
a=int(input("first value"))
b=int(input("first value"))

print(f"{1/2*(a*b)}")
# Out:
# first value 12
# first value 4
# 24.0

# %%
# Out:
# 3

# %%
a=2 
b=3
print(a+b)
# Out:
# 5

# %%
def hello():
    
    return"hello"

hello()
# Out:
#   Cell In[11], line 4
#     return"hello"
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def hello():
    return"hello"

hello()
# Out:
# 'hello'

# %% [markdown]
# # Operators & Expressions
#
#
# ### /	Division	5/2
# ###  //	Floor Division	5//2
# ###  %	Modulus	5%2

# %%
print(10/3)
# Out:
# 3.3333333333333335

# %%
print(10//3)
# Out:
# 3

# %%
print(10%3)
# Out:
# 1

# %%
print(-10/3)
print(-10//3)
# Out:
# -3.3333333333333335
# -4

# %%
# write a code that do all the airhmatics operations

var_1 =int(input("value 1"))

var_2=int(input("value 2"))

print(f"addition {var_1+var_2}")
print(f"sub {var_1 - var_2}")
print(f"mul {var_1*var_2}")
print(f"div {var_1/var_2}")
print(f"floar div {var_1//var_2}")
print(f"modlus {var_1%var_2}")
print(f"exponential {var_1**var_2}")
# Out:
# value 1 20
# value 2 3
# addition 23
# sub 17
# mul 60
# div 6.666666666666667
# floar div 6
# modlus 2
# exponential 8000

# %% [markdown]
# ## Assignment Operators

# %%
x=0
y=2
x+=y # x=x+y

print(x)
# Out:
# 2

# %%
20==20
# Out:
# True

# %%
val_1 = int(input("first value"))

val_2 = int(input("2nd value"))

print(f"{val_1}=={val_2} -> {val_1==val_2}")
print(f"{val_1}!={val_2} -> {val_1!=val_2}")
print(f"{val_1}>{val_2} -> {val_1>val_2}")
print(f"{val_1}<{val_2} -> {val_1<val_2}")
print(f"{val_1}>={val_2} -> {val_1>=val_2}")
print(f"{val_1}<={val_2} -> {val_1<=val_2}")
# Out:
# first value 1
# 2nd value 2
# 1==2 -> False
# 1!=2 -> True
# 1>2 -> False
# 1<2 -> True
# 1>=2 -> False
# 1<=2 -> True

# %%
age=0
print(not age)
# Out:
# True
